# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
# Import necessary libraries
# For making HTTP requests to IMDb
import requests
# For parsing HTML content
from bs4 import BeautifulSoup
# For data manipulation and saving to CSV
import pandas as pd

# Define a function to get reviews from IMDb
def get_reviews(movie_id, max_reviews):
    reviews = []
    current_page = 1 # Start from the first page of reviews
    
     # Continue fetching reviews until we reach the desired number
    while len(reviews) < max_reviews:
        # Construct the URL for fetching reviews, using the movie ID
        url = f"https://www.imdb.com/title/{movie_id}/reviews/?ref_=tt_ql_2"
        params = {
            'spoiler': 'hide',
            'sort': 'helpfulnessScore',
            'dir': 'desc',
            'ratingFilter': '0',
            'paginationKey': '',  
        }
        response = requests.get(url, params=params)
        soup = BeautifulSoup(response.content, 'html.parser')
        
         # Find all review blocks on the page
        review_blocks = soup.find_all('div', class_='lister-item-content')
        if not review_blocks:
            break  # Break if no more reviews are found or if blocked

        # Extract the title and review text from each block    
        for block in review_blocks:
            title = block.find('a', class_='title').text.strip()
            review_text = block.find('div', class_='text show-more__control').text.strip()
            reviews.append({'title': title, 'review': review_text})
            if len(reviews) >= max_reviews:
                break

        current_page += 1  

    return reviews[:max_reviews] # Return the collected reviews, up to the specified maximum number

def save_reviews_to_csv(reviews, filename):
    df = pd.DataFrame(reviews)
    df.to_csv(filename, index=False)

# Example movie ID for POOR THINGS movie 
movie_id = 'tt14230458'
max_reviews = 1000 # Set the desired number of reviews to fetch
# Call the get_reviews function with the movie ID and number of reviews
reviews = get_reviews(movie_id, max_reviews)
# Save the fetched reviews to a CSV file
save_reviews_to_csv(reviews, 'imdb_User_reviews.csv')

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.

import pandas as pd
import re
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords

# Ensure that necessary NLTK resources are downloaded
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Load the CSV file
df = pd.read_csv('imdb_User_reviews.csv')  # Update the file path

# If NLTK's stopwords can't be downloaded, define a list of stopwords manually
stop_words = set(stopwords.words('english'))

# Initialize Stemmer and Lemmatizer for text normalization
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    # 1- Remove special characters and punctuations
    # This uses a regex to keep only word characters (letters and numbers) and whitespace, effectively removing punctuation.
    text = re.sub(r'[^\w\s]', '', text)
    
    # 2- Remove numbers
    # This uses a regex to remove digits from the text.
    text = re.sub(r'\d+', '', text)
    
    # 4- Lowercase all texts
    # This is important for consistency and to ensure that the same word in different cases is treated as the same word.
    text = text.lower()
    
    # 3- Remove stopwords
    # Stopwords are common words that are usually removed in the preprocessing phase because they contribute little to the overall meaning of the text.
    text = ' '.join([word for word in text.split() if word not in stop_words])
    
    # 5- Stemming
    # Stemming reduces words to their word stem or root form (e.g., "running" -> "run").
    text = ' '.join([stemmer.stem(word) for word in text.split()])
    
    # 6- Lemmatization
    # Lemmatization reduces words to their base or dictionary form (e.g., "better" -> "good").
    text = ' '.join([lemmatizer.lemmatize(word) for word in text.split()])
    
    return text

# Assuming the text data is in a column named 'text'
df['cleaned_review'] = df['review'].apply(clean_text)

# Save the DataFrame to a new CSV file
df.to_csv('cleaned_imdb_User_reviews.csv', index=False)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/narendranathreddy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/narendranathreddy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/narendranathreddy/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.10.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (8.1.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: jinja2 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.4.5)
# Requirement already satisfied: setuptools in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (63.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.3)
# Requirement already satisfied: pathy>=0.3.5 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.10.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/narendranathreddy/opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)

# %%
# !python -m spacy download en_core_web_sm

# %%
# Import necessary libraries
import stanza
from collections import Counter
import pandas as pd

# Load the cleaned text data
df = pd.read_csv('cleaned_imdb_User_reviews.csv')  # Update the file path accordingly

# Initialize the Stanza NLP pipeline for English language
# specifying the processors we want to use
nlp = stanza.Pipeline(lang='en', processors='tokenize,pos,lemma,constituency,depparse,ner')
class PosTagCounter(object):
    #The class that counts the number of pos tags of various types in a sentence.
    def __init__(self, stanza_doc):
        #The initialization method that takes a Stanza document as input.
        self.stanza_doc = stanza_doc

    def get_pos_tag_count(self, pos_tag):
        #Returns the number of specific POS tags.
        count = 0
        for sentence in self.stanza_doc.sentences:
            count += len([word for word in sentence.words if word.pos == pos_tag])
        return count

# Extract the first review from the dataset for demonstration
example_text = df['cleaned_review'].iloc[0]  # Taking the first cleaned text for demonstration

# Process the text with Stanza to create a document object
doc = nlp(example_text)

# POS Tagging and Counting
pos_counter = PosTagCounter(doc)
nouns_count = pos_counter.get_pos_tag_count('NOUN')
verbs_count = pos_counter.get_pos_tag_count('VERB')
adjectives_count = pos_counter.get_pos_tag_count('ADJ')
adverbs_count = pos_counter.get_pos_tag_count('ADV')

# Print counts of different parts of speech
print(f"Nouns: {nouns_count}, Verbs: {verbs_count}, Adjectives: {adjectives_count}, Adverbs: {adverbs_count}")

# Constituency Parsing
# Print the constituency parse tree of the first sentence in the document
print("Constituency Parsing Tree of the first sentence:")
print(doc.sentences[0].constituency)

# Dependency Parsing
# Print the dependency parse tree of the first sentence in the document
print("\nDependency Parsing Tree of the first sentence:")
for dep_edge in doc.sentences[0].dependencies:
    print(dep_edge)

# Named Entity Recognition
entity_types = []

# Loop through each review in the dataset, process it, and collect named entities
for review in df['cleaned_review']:
    doc = nlp(review)
    entity_types.extend([ent.type for ent in doc.ents])

# Count and print the frequency of different types of named entities in the dataset
entity_counter = Counter(entity_types)

print("\nNamed Entities and their counts:")
print(entity_counter)
# Out:
# 2024-02-26 15:13:41 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-02-26 15:13:41 INFO: Downloaded file to /Users/narendranathreddy/stanza_resources/resources.json
# 2024-02-26 15:13:41 WARNING: Language en package default expects mwt, which has been added
# 2024-02-26 15:13:43 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-02-26 15:13:43 INFO: Using device: cpu
# 2024-02-26 15:13:43 INFO: Loading: tokenize
# 2024-02-26 15:13:43 INFO: Loading: mwt
# 2024-02-26 15:13:43 INFO: Loading: pos
# 2024-02-26 15:13:43 INFO: Loading: lemma
# 2024-02-26 15:13:43 INFO: Loading: constituency
# 2024-02-26 15:13:43 INFO: Loading: depparse
# 2024-02-26 15:13:43 INFO: Loading: ner
# 2024-02-26 15:13:44 INFO: Done loading processors!
# Nouns: 42, Verbs: 11, Adjectives: 13, Adverbs: 9
# Constituency Parsing Tree of the first sentence:
# (ROOT (NP (NP (ADJP (FW youv) (VBN seen)) (FW yorgo) (FW lathimo) (NN film) (JJ poor) (NN thing)) (SBAR (S (NP (NN everyth)) (VP (MD would) (VP (VB expect) (NP (NN hope)) (VP (ADJP (RB havent) (VBN seen)) (NP (NP (NN film) (NN buckl)) (SBAR (WDT that) (S (NP (NP (ADJP (JJ ill) (FW saypoor)) (NN thing)) (ADJP (FW thoroughli) (FW outrag) (FW romp)) (FW trippi) (FW disturb) (NP (JJ brutal) (FW funni) (FW could))) (FW summar) (NN film) (FW essenti) (FW feminist) (FW spin) (FW clockwork) (FW orang) (FW filmsnovel) (FW explor) (FW concept) (NML (FW freewil) (FW oppress) (FW societi)) (FW alex) (FW struggl) (FW repugn) (NML (FW urg) (FW ultraviol) (FW bella) (FW struggl) (FW normal) (FW primal) (FW urg) (FW sexual) (FW liber) (FW independ) (FW woman) (FW expect) (NP (FW dystopian) (FW univers)) (S (NP (ADJP (FW bella) (FW opposit) (FW much)) (FW chagrin) (FW male) (FW caretak)) (FW despit) (NP (NML (FW creat) (FW laboratori) (FW mad) (FW scientist)) (FW saddl) (NML (NML (FW brain) (FW infant)) (FW child)) (FW pregnant) (FW bella) (FW form) (FW insati) (FW appetit) (FW explor) (FW thrivingpoor) (FW thing) (FW celebr) (FW hedon) (FW way) (SBAR (FW that) (S (NP (JJ honest) (FW humor) (FW lathimo)) (VP (FW find) (NP (FW freewil) (FW necessari) (NML (NML (FW air) (FW breath)) (FW time)))))) (FW challeng) (NP (NML (FW socal) (FW polit)) (FW societi) (FW consid) (S (NP (NML (FW bella) (FW avatar)) (FW id) (FW perhap) (FW consid) (FW pioneer) (FW rebel) (FW whatev) (VB impress)) (VP (VB make) (S (S (ADJP (VBN blown) (RB away))) (NP (NNP bella) (FW truli) (NN heart) (NN soul) (NN entir) (NN movi) (VP (JJ defin) (NP (NN role) (NML (NML (NML (NML (NN emma) (NN stone)) (NN career)) (NN captur)) (NN level)) (NN vulner) (NN ach) (NNP desir)) (ADVP (RB havent) (VBN seen)) (S (NP (NN actor) (JJ long) (NN timepoor) (NN thing)) (VP (VB hold) (NP (ADVP (ADVP (NN noth) (RB back)) (PRP$ there)) (NP (NML (NML (NN lot) (NN sex)) (NN lot)) (NP (JJ awkward) (JJ unsexi) (NN sex)))) (RB perhap) (S (NP (JJ realist) (NN sex)) (ADVP (RB weve)) (ADVP (RB ever)) (VP (VBN seen) (NP (NP (NML (NN film) (JJ special) (NN effect)) (JJS strangest) (NN inspir) (NN lathimoss)) (NML (JJ entir) (NN career) (NNP mark)) (S (ADVP (NNP ruffalo)) (VP (VB perform) (S (NP (NNP duncan) (ADVP (RB far) (NN year)) (JJS best)) (VP (NN comed) (VP (NN performanceif)) (NP (NP (PRP$ your) (NN look)) (NN cinemat)) (VP (NN spectacl) (NP (NP (NN holiday) (NN season)) (SBAR (S (NP (PRP youv)) (VP (VBD found) (ADVP (RB right)))))))))))))))))))))))))))))))))))
#
# Dependency Parsing Tree of the first sentence:
# ({
#   "id": 2,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 7,
#   "deprel": "amod",
#   "start_char": 5,
#   "end_char": 9
# }, 'nsubj:pass', {
#   "id": 1,
#   "text": "youv",
#   "lemma": "youv",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 2,
#   "deprel": "nsubj:pass",
#   "start_char": 0,
#   "end_char": 4
# })
# ({
#   "id": 7,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "nsubj",
#   "start_char": 34,
#   "end_char": 39
# }, 'amod', {
#   "id": 2,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 7,
#   "deprel": "amod",
#   "start_char": 5,
#   "end_char": 9
# })
# ({
#   "id": 2,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 7,
#   "deprel": "amod",
#   "start_char": 5,
#   "end_char": 9
# }, 'obj', {
#   "id": 3,
#   "text": "yorgo",
#   "lemma": "yorgo",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 2,
#   "deprel": "obj",
#   "start_char": 10,
#   "end_char": 15
# })
# ({
#   "id": 7,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "nsubj",
#   "start_char": 34,
#   "end_char": 39
# }, 'compound', {
#   "id": 4,
#   "text": "lathimo",
#   "lemma": "lathimo",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 7,
#   "deprel": "compound",
#   "start_char": 16,
#   "end_char": 23
# })
# ({
#   "id": 7,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "nsubj",
#   "start_char": 34,
#   "end_char": 39
# }, 'compound', {
#   "id": 5,
#   "text": "film",
#   "lemma": "film",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 7,
#   "deprel": "compound",
#   "start_char": 24,
#   "end_char": 28
# })
# ({
#   "id": 7,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "nsubj",
#   "start_char": 34,
#   "end_char": 39
# }, 'amod', {
#   "id": 6,
#   "text": "poor",
#   "lemma": "poor",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 7,
#   "deprel": "amod",
#   "start_char": 29,
#   "end_char": 33
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'nsubj', {
#   "id": 7,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "nsubj",
#   "start_char": 34,
#   "end_char": 39
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'nsubj', {
#   "id": 8,
#   "text": "everyth",
#   "lemma": "everyth",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "nsubj",
#   "start_char": 40,
#   "end_char": 47
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'aux', {
#   "id": 9,
#   "text": "would",
#   "lemma": "would",
#   "upos": "AUX",
#   "xpos": "MD",
#   "feats": "VerbForm=Fin",
#   "head": 10,
#   "deprel": "aux",
#   "start_char": 48,
#   "end_char": 53
# })
# ({
#   "id": 0,
#   "text": "ROOT"
# }, 'root', {
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'obj', {
#   "id": 11,
#   "text": "hope",
#   "lemma": "hope",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "obj",
#   "start_char": 61,
#   "end_char": 65
# })
# ({
#   "id": 13,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "ccomp",
#   "start_char": 73,
#   "end_char": 77
# }, 'advmod', {
#   "id": 12,
#   "text": "havent",
#   "lemma": "havent",
#   "upos": "ADV",
#   "xpos": "RB",
#   "head": 13,
#   "deprel": "advmod",
#   "start_char": 66,
#   "end_char": 72
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'ccomp', {
#   "id": 13,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "ccomp",
#   "start_char": 73,
#   "end_char": 77
# })
# ({
#   "id": 15,
#   "text": "buckl",
#   "lemma": "buckl",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "obj",
#   "start_char": 83,
#   "end_char": 88
# }, 'compound', {
#   "id": 14,
#   "text": "film",
#   "lemma": "film",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 15,
#   "deprel": "compound",
#   "start_char": 78,
#   "end_char": 82
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'obj', {
#   "id": 15,
#   "text": "buckl",
#   "lemma": "buckl",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "obj",
#   "start_char": 83,
#   "end_char": 88
# })
# ({
#   "id": 19,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 20,
#   "deprel": "compound",
#   "start_char": 106,
#   "end_char": 111
# }, 'det', {
#   "id": 16,
#   "text": "that",
#   "lemma": "that",
#   "upos": "PRON",
#   "xpos": "WDT",
#   "feats": "PronType=Rel",
#   "head": 19,
#   "deprel": "det",
#   "start_char": 89,
#   "end_char": 93
# })
# ({
#   "id": 18,
#   "text": "saypoor",
#   "lemma": "saypoor",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 19,
#   "deprel": "compound",
#   "start_char": 98,
#   "end_char": 105
# }, 'amod', {
#   "id": 17,
#   "text": "ill",
#   "lemma": "ill",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 18,
#   "deprel": "amod",
#   "start_char": 94,
#   "end_char": 97
# })
# ({
#   "id": 19,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 20,
#   "deprel": "compound",
#   "start_char": 106,
#   "end_char": 111
# }, 'compound', {
#   "id": 18,
#   "text": "saypoor",
#   "lemma": "saypoor",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 19,
#   "deprel": "compound",
#   "start_char": 98,
#   "end_char": 105
# })
# ({
#   "id": 20,
#   "text": "thoroughli",
#   "lemma": "thoroughli",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 21,
#   "deprel": "compound",
#   "start_char": 112,
#   "end_char": 122
# }, 'compound', {
#   "id": 19,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 20,
#   "deprel": "compound",
#   "start_char": 106,
#   "end_char": 111
# })
# ({
#   "id": 21,
#   "text": "outrag",
#   "lemma": "outrag",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 23,
#   "deprel": "compound",
#   "start_char": 123,
#   "end_char": 129
# }, 'compound', {
#   "id": 20,
#   "text": "thoroughli",
#   "lemma": "thoroughli",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 21,
#   "deprel": "compound",
#   "start_char": 112,
#   "end_char": 122
# })
# ({
#   "id": 23,
#   "text": "trippi",
#   "lemma": "trippi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 135,
#   "end_char": 141
# }, 'compound', {
#   "id": 21,
#   "text": "outrag",
#   "lemma": "outrag",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 23,
#   "deprel": "compound",
#   "start_char": 123,
#   "end_char": 129
# })
# ({
#   "id": 23,
#   "text": "trippi",
#   "lemma": "trippi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 135,
#   "end_char": 141
# }, 'compound', {
#   "id": 22,
#   "text": "romp",
#   "lemma": "romp",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 23,
#   "deprel": "compound",
#   "start_char": 130,
#   "end_char": 134
# })
# ({
#   "id": 15,
#   "text": "buckl",
#   "lemma": "buckl",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "obj",
#   "start_char": 83,
#   "end_char": 88
# }, 'conj', {
#   "id": 23,
#   "text": "trippi",
#   "lemma": "trippi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 135,
#   "end_char": 141
# })
# ({
#   "id": 26,
#   "text": "funni",
#   "lemma": "funni",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 23,
#   "deprel": "conj",
#   "start_char": 157,
#   "end_char": 162
# }, 'conj', {
#   "id": 24,
#   "text": "disturb",
#   "lemma": "disturb",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 26,
#   "deprel": "conj",
#   "start_char": 142,
#   "end_char": 149
# })
# ({
#   "id": 26,
#   "text": "funni",
#   "lemma": "funni",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 23,
#   "deprel": "conj",
#   "start_char": 157,
#   "end_char": 162
# }, 'amod', {
#   "id": 25,
#   "text": "brutal",
#   "lemma": "brutal",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 26,
#   "deprel": "amod",
#   "start_char": 150,
#   "end_char": 156
# })
# ({
#   "id": 23,
#   "text": "trippi",
#   "lemma": "trippi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 135,
#   "end_char": 141
# }, 'conj', {
#   "id": 26,
#   "text": "funni",
#   "lemma": "funni",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 23,
#   "deprel": "conj",
#   "start_char": 157,
#   "end_char": 162
# })
# ({
#   "id": 23,
#   "text": "trippi",
#   "lemma": "trippi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 135,
#   "end_char": 141
# }, 'conj', {
#   "id": 27,
#   "text": "could",
#   "lemma": "could",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 23,
#   "deprel": "conj",
#   "start_char": 163,
#   "end_char": 168
# })
# ({
#   "id": 30,
#   "text": "essenti",
#   "lemma": "essenti",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 31,
#   "deprel": "compound",
#   "start_char": 181,
#   "end_char": 188
# }, 'compound', {
#   "id": 28,
#   "text": "summar",
#   "lemma": "summar",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 30,
#   "deprel": "compound",
#   "start_char": 169,
#   "end_char": 175
# })
# ({
#   "id": 31,
#   "text": "feminist",
#   "lemma": "feminist",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 33,
#   "deprel": "appos",
#   "start_char": 189,
#   "end_char": 197
# }, 'compound', {
#   "id": 29,
#   "text": "film",
#   "lemma": "film",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 31,
#   "deprel": "compound",
#   "start_char": 176,
#   "end_char": 180
# })
# ({
#   "id": 31,
#   "text": "feminist",
#   "lemma": "feminist",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 33,
#   "deprel": "appos",
#   "start_char": 189,
#   "end_char": 197
# }, 'compound', {
#   "id": 30,
#   "text": "essenti",
#   "lemma": "essenti",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 31,
#   "deprel": "compound",
#   "start_char": 181,
#   "end_char": 188
# })
# ({
#   "id": 33,
#   "text": "clockwork",
#   "lemma": "Clockwork",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 203,
#   "end_char": 212
# }, 'appos', {
#   "id": 31,
#   "text": "feminist",
#   "lemma": "feminist",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 33,
#   "deprel": "appos",
#   "start_char": 189,
#   "end_char": 197
# })
# ({
#   "id": 33,
#   "text": "clockwork",
#   "lemma": "Clockwork",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 203,
#   "end_char": 212
# }, 'compound', {
#   "id": 32,
#   "text": "spin",
#   "lemma": "spin",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 33,
#   "deprel": "compound",
#   "start_char": 198,
#   "end_char": 202
# })
# ({
#   "id": 15,
#   "text": "buckl",
#   "lemma": "buckl",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "obj",
#   "start_char": 83,
#   "end_char": 88
# }, 'conj', {
#   "id": 33,
#   "text": "clockwork",
#   "lemma": "Clockwork",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 203,
#   "end_char": 212
# })
# ({
#   "id": 33,
#   "text": "clockwork",
#   "lemma": "Clockwork",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 203,
#   "end_char": 212
# }, 'appos', {
#   "id": 34,
#   "text": "orang",
#   "lemma": "orang",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 33,
#   "deprel": "appos",
#   "start_char": 213,
#   "end_char": 218
# })
# ({
#   "id": 15,
#   "text": "buckl",
#   "lemma": "buckl",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 10,
#   "deprel": "obj",
#   "start_char": 83,
#   "end_char": 88
# }, 'conj', {
#   "id": 35,
#   "text": "filmsnovel",
#   "lemma": "filmsnovel",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 15,
#   "deprel": "conj",
#   "start_char": 219,
#   "end_char": 229
# })
# ({
#   "id": 37,
#   "text": "concept",
#   "lemma": "concept",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 237,
#   "end_char": 244
# }, 'conj', {
#   "id": 36,
#   "text": "explor",
#   "lemma": "explor",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 37,
#   "deprel": "conj",
#   "start_char": 230,
#   "end_char": 236
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'conj', {
#   "id": 37,
#   "text": "concept",
#   "lemma": "concept",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 237,
#   "end_char": 244
# })
# ({
#   "id": 39,
#   "text": "oppress",
#   "lemma": "oppress",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 253,
#   "end_char": 260
# }, 'conj', {
#   "id": 38,
#   "text": "freewil",
#   "lemma": "freewil",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 39,
#   "deprel": "conj",
#   "start_char": 245,
#   "end_char": 252
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'parataxis', {
#   "id": 39,
#   "text": "oppress",
#   "lemma": "oppress",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 253,
#   "end_char": 260
# })
# ({
#   "id": 41,
#   "text": "alex",
#   "lemma": "alex",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 43,
#   "deprel": "conj",
#   "start_char": 269,
#   "end_char": 273
# }, 'nmod', {
#   "id": 40,
#   "text": "societi",
#   "lemma": "societi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 41,
#   "deprel": "nmod",
#   "start_char": 261,
#   "end_char": 268
# })
# ({
#   "id": 43,
#   "text": "repugn",
#   "lemma": "repugn",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 282,
#   "end_char": 288
# }, 'conj', {
#   "id": 41,
#   "text": "alex",
#   "lemma": "alex",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 43,
#   "deprel": "conj",
#   "start_char": 269,
#   "end_char": 273
# })
# ({
#   "id": 43,
#   "text": "repugn",
#   "lemma": "repugn",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 282,
#   "end_char": 288
# }, 'conj', {
#   "id": 42,
#   "text": "struggl",
#   "lemma": "struggl",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 43,
#   "deprel": "conj",
#   "start_char": 274,
#   "end_char": 281
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'conj', {
#   "id": 43,
#   "text": "repugn",
#   "lemma": "repugn",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 282,
#   "end_char": 288
# })
# ({
#   "id": 46,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 47,
#   "deprel": "conj",
#   "start_char": 303,
#   "end_char": 308
# }, 'conj', {
#   "id": 44,
#   "text": "urg",
#   "lemma": "urg",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 46,
#   "deprel": "conj",
#   "start_char": 289,
#   "end_char": 292
# })
# ({
#   "id": 46,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 47,
#   "deprel": "conj",
#   "start_char": 303,
#   "end_char": 308
# }, 'compound', {
#   "id": 45,
#   "text": "ultraviol",
#   "lemma": "ultraviol",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 46,
#   "deprel": "compound",
#   "start_char": 293,
#   "end_char": 302
# })
# ({
#   "id": 47,
#   "text": "struggl",
#   "lemma": "struggl",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 49,
#   "deprel": "conj",
#   "start_char": 309,
#   "end_char": 316
# }, 'conj', {
#   "id": 46,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 47,
#   "deprel": "conj",
#   "start_char": 303,
#   "end_char": 308
# })
# ({
#   "id": 49,
#   "text": "primal",
#   "lemma": "primal",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 50,
#   "deprel": "compound",
#   "start_char": 324,
#   "end_char": 330
# }, 'conj', {
#   "id": 47,
#   "text": "struggl",
#   "lemma": "struggl",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 49,
#   "deprel": "conj",
#   "start_char": 309,
#   "end_char": 316
# })
# ({
#   "id": 50,
#   "text": "urg",
#   "lemma": "urg",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 51,
#   "deprel": "conj",
#   "start_char": 331,
#   "end_char": 334
# }, 'compound', {
#   "id": 48,
#   "text": "normal",
#   "lemma": "normal",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 50,
#   "deprel": "compound",
#   "start_char": 317,
#   "end_char": 323
# })
# ({
#   "id": 50,
#   "text": "urg",
#   "lemma": "urg",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 51,
#   "deprel": "conj",
#   "start_char": 331,
#   "end_char": 334
# }, 'compound', {
#   "id": 49,
#   "text": "primal",
#   "lemma": "primal",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 50,
#   "deprel": "compound",
#   "start_char": 324,
#   "end_char": 330
# })
# ({
#   "id": 51,
#   "text": "sexual",
#   "lemma": "sexual",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 52,
#   "deprel": "compound",
#   "start_char": 335,
#   "end_char": 341
# }, 'conj', {
#   "id": 50,
#   "text": "urg",
#   "lemma": "urg",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 51,
#   "deprel": "conj",
#   "start_char": 331,
#   "end_char": 334
# })
# ({
#   "id": 52,
#   "text": "liber",
#   "lemma": "liber",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 54,
#   "deprel": "conj",
#   "start_char": 342,
#   "end_char": 347
# }, 'compound', {
#   "id": 51,
#   "text": "sexual",
#   "lemma": "sexual",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 52,
#   "deprel": "compound",
#   "start_char": 335,
#   "end_char": 341
# })
# ({
#   "id": 54,
#   "text": "woman",
#   "lemma": "woman",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 357,
#   "end_char": 362
# }, 'conj', {
#   "id": 52,
#   "text": "liber",
#   "lemma": "liber",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 54,
#   "deprel": "conj",
#   "start_char": 342,
#   "end_char": 347
# })
# ({
#   "id": 54,
#   "text": "woman",
#   "lemma": "woman",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 357,
#   "end_char": 362
# }, 'conj', {
#   "id": 53,
#   "text": "independ",
#   "lemma": "independ",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 54,
#   "deprel": "conj",
#   "start_char": 348,
#   "end_char": 356
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'conj', {
#   "id": 54,
#   "text": "woman",
#   "lemma": "woman",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 357,
#   "end_char": 362
# })
# ({
#   "id": 54,
#   "text": "woman",
#   "lemma": "woman",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 357,
#   "end_char": 362
# }, 'conj', {
#   "id": 55,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 54,
#   "deprel": "conj",
#   "start_char": 363,
#   "end_char": 369
# })
# ({
#   "id": 54,
#   "text": "woman",
#   "lemma": "woman",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 357,
#   "end_char": 362
# }, 'conj', {
#   "id": 56,
#   "text": "dystopian",
#   "lemma": "dystopian",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 54,
#   "deprel": "conj",
#   "start_char": 370,
#   "end_char": 379
# })
# ({
#   "id": 58,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 59,
#   "deprel": "conj",
#   "start_char": 388,
#   "end_char": 393
# }, 'conj', {
#   "id": 57,
#   "text": "univers",
#   "lemma": "univer",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 58,
#   "deprel": "conj",
#   "start_char": 380,
#   "end_char": 387
# })
# ({
#   "id": 59,
#   "text": "opposit",
#   "lemma": "opposit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 61,
#   "deprel": "conj",
#   "start_char": 394,
#   "end_char": 401
# }, 'conj', {
#   "id": 58,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 59,
#   "deprel": "conj",
#   "start_char": 388,
#   "end_char": 393
# })
# ({
#   "id": 61,
#   "text": "chagrin",
#   "lemma": "chagrin",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 63,
#   "deprel": "conj",
#   "start_char": 407,
#   "end_char": 414
# }, 'conj', {
#   "id": 59,
#   "text": "opposit",
#   "lemma": "opposit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 61,
#   "deprel": "conj",
#   "start_char": 394,
#   "end_char": 401
# })
# ({
#   "id": 61,
#   "text": "chagrin",
#   "lemma": "chagrin",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 63,
#   "deprel": "conj",
#   "start_char": 407,
#   "end_char": 414
# }, 'conj', {
#   "id": 60,
#   "text": "much",
#   "lemma": "much",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 61,
#   "deprel": "conj",
#   "start_char": 402,
#   "end_char": 406
# })
# ({
#   "id": 63,
#   "text": "caretak",
#   "lemma": "caretak",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 64,
#   "deprel": "conj",
#   "start_char": 420,
#   "end_char": 427
# }, 'conj', {
#   "id": 61,
#   "text": "chagrin",
#   "lemma": "chagrin",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 63,
#   "deprel": "conj",
#   "start_char": 407,
#   "end_char": 414
# })
# ({
#   "id": 63,
#   "text": "caretak",
#   "lemma": "caretak",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 64,
#   "deprel": "conj",
#   "start_char": 420,
#   "end_char": 427
# }, 'compound', {
#   "id": 62,
#   "text": "male",
#   "lemma": "male",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 63,
#   "deprel": "compound",
#   "start_char": 415,
#   "end_char": 419
# })
# ({
#   "id": 64,
#   "text": "despit",
#   "lemma": "despit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 65,
#   "deprel": "flat",
#   "start_char": 428,
#   "end_char": 434
# }, 'conj', {
#   "id": 63,
#   "text": "caretak",
#   "lemma": "caretak",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 64,
#   "deprel": "conj",
#   "start_char": 420,
#   "end_char": 427
# })
# ({
#   "id": 65,
#   "text": "creat",
#   "lemma": "creat",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 66,
#   "deprel": "compound",
#   "start_char": 435,
#   "end_char": 440
# }, 'flat', {
#   "id": 64,
#   "text": "despit",
#   "lemma": "despit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 65,
#   "deprel": "flat",
#   "start_char": 428,
#   "end_char": 434
# })
# ({
#   "id": 66,
#   "text": "laboratori",
#   "lemma": "laboratori",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 68,
#   "deprel": "flat",
#   "start_char": 441,
#   "end_char": 451
# }, 'compound', {
#   "id": 65,
#   "text": "creat",
#   "lemma": "creat",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 66,
#   "deprel": "compound",
#   "start_char": 435,
#   "end_char": 440
# })
# ({
#   "id": 68,
#   "text": "scientist",
#   "lemma": "scientist",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 69,
#   "deprel": "conj",
#   "start_char": 456,
#   "end_char": 465
# }, 'flat', {
#   "id": 66,
#   "text": "laboratori",
#   "lemma": "laboratori",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 68,
#   "deprel": "flat",
#   "start_char": 441,
#   "end_char": 451
# })
# ({
#   "id": 68,
#   "text": "scientist",
#   "lemma": "scientist",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 69,
#   "deprel": "conj",
#   "start_char": 456,
#   "end_char": 465
# }, 'compound', {
#   "id": 67,
#   "text": "mad",
#   "lemma": "mad",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 68,
#   "deprel": "compound",
#   "start_char": 452,
#   "end_char": 455
# })
# ({
#   "id": 69,
#   "text": "saddl",
#   "lemma": "saddl",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 70,
#   "deprel": "compound",
#   "start_char": 466,
#   "end_char": 471
# }, 'conj', {
#   "id": 68,
#   "text": "scientist",
#   "lemma": "scientist",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 69,
#   "deprel": "conj",
#   "start_char": 456,
#   "end_char": 465
# })
# ({
#   "id": 70,
#   "text": "brain",
#   "lemma": "brain",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 71,
#   "deprel": "compound",
#   "start_char": 472,
#   "end_char": 477
# }, 'compound', {
#   "id": 69,
#   "text": "saddl",
#   "lemma": "saddl",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 70,
#   "deprel": "compound",
#   "start_char": 466,
#   "end_char": 471
# })
# ({
#   "id": 71,
#   "text": "infant",
#   "lemma": "infant",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 73,
#   "deprel": "compound",
#   "start_char": 478,
#   "end_char": 484
# }, 'compound', {
#   "id": 70,
#   "text": "brain",
#   "lemma": "brain",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 71,
#   "deprel": "compound",
#   "start_char": 472,
#   "end_char": 477
# })
# ({
#   "id": 73,
#   "text": "pregnant",
#   "lemma": "pregnant",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 74,
#   "deprel": "compound",
#   "start_char": 491,
#   "end_char": 499
# }, 'compound', {
#   "id": 71,
#   "text": "infant",
#   "lemma": "infant",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 73,
#   "deprel": "compound",
#   "start_char": 478,
#   "end_char": 484
# })
# ({
#   "id": 73,
#   "text": "pregnant",
#   "lemma": "pregnant",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 74,
#   "deprel": "compound",
#   "start_char": 491,
#   "end_char": 499
# }, 'compound', {
#   "id": 72,
#   "text": "child",
#   "lemma": "child",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 73,
#   "deprel": "compound",
#   "start_char": 485,
#   "end_char": 490
# })
# ({
#   "id": 74,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 75,
#   "deprel": "compound",
#   "start_char": 500,
#   "end_char": 505
# }, 'compound', {
#   "id": 73,
#   "text": "pregnant",
#   "lemma": "pregnant",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 74,
#   "deprel": "compound",
#   "start_char": 491,
#   "end_char": 499
# })
# ({
#   "id": 75,
#   "text": "form",
#   "lemma": "form",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 77,
#   "deprel": "compound",
#   "start_char": 506,
#   "end_char": 510
# }, 'compound', {
#   "id": 74,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 75,
#   "deprel": "compound",
#   "start_char": 500,
#   "end_char": 505
# })
# ({
#   "id": 77,
#   "text": "appetit",
#   "lemma": "appetit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 78,
#   "deprel": "compound",
#   "start_char": 518,
#   "end_char": 525
# }, 'compound', {
#   "id": 75,
#   "text": "form",
#   "lemma": "form",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 77,
#   "deprel": "compound",
#   "start_char": 506,
#   "end_char": 510
# })
# ({
#   "id": 77,
#   "text": "appetit",
#   "lemma": "appetit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 78,
#   "deprel": "compound",
#   "start_char": 518,
#   "end_char": 525
# }, 'compound', {
#   "id": 76,
#   "text": "insati",
#   "lemma": "insati",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 77,
#   "deprel": "compound",
#   "start_char": 511,
#   "end_char": 517
# })
# ({
#   "id": 78,
#   "text": "explor",
#   "lemma": "explor",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 526,
#   "end_char": 532
# }, 'compound', {
#   "id": 77,
#   "text": "appetit",
#   "lemma": "appetit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 78,
#   "deprel": "compound",
#   "start_char": 518,
#   "end_char": 525
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'conj', {
#   "id": 78,
#   "text": "explor",
#   "lemma": "explor",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 526,
#   "end_char": 532
# })
# ({
#   "id": 78,
#   "text": "explor",
#   "lemma": "explor",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 526,
#   "end_char": 532
# }, 'flat', {
#   "id": 79,
#   "text": "thrivingpoor",
#   "lemma": "thrivingpoor",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 78,
#   "deprel": "flat",
#   "start_char": 533,
#   "end_char": 545
# })
# ({
#   "id": 81,
#   "text": "celebr",
#   "lemma": "celebr",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 82,
#   "deprel": "compound",
#   "start_char": 552,
#   "end_char": 558
# }, 'flat', {
#   "id": 80,
#   "text": "thing",
#   "lemma": "thing",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 81,
#   "deprel": "flat",
#   "start_char": 546,
#   "end_char": 551
# })
# ({
#   "id": 82,
#   "text": "hedon",
#   "lemma": "hedon",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 83,
#   "deprel": "compound",
#   "start_char": 559,
#   "end_char": 564
# }, 'compound', {
#   "id": 81,
#   "text": "celebr",
#   "lemma": "celebr",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 82,
#   "deprel": "compound",
#   "start_char": 552,
#   "end_char": 558
# })
# ({
#   "id": 83,
#   "text": "way",
#   "lemma": "way",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 84,
#   "deprel": "flat",
#   "start_char": 565,
#   "end_char": 568
# }, 'compound', {
#   "id": 82,
#   "text": "hedon",
#   "lemma": "hedon",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 83,
#   "deprel": "compound",
#   "start_char": 559,
#   "end_char": 564
# })
# ({
#   "id": 84,
#   "text": "that",
#   "lemma": "that",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 86,
#   "deprel": "nmod",
#   "start_char": 569,
#   "end_char": 573
# }, 'flat', {
#   "id": 83,
#   "text": "way",
#   "lemma": "way",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 84,
#   "deprel": "flat",
#   "start_char": 565,
#   "end_char": 568
# })
# ({
#   "id": 86,
#   "text": "humor",
#   "lemma": "humor",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 87,
#   "deprel": "compound",
#   "start_char": 581,
#   "end_char": 586
# }, 'nmod', {
#   "id": 84,
#   "text": "that",
#   "lemma": "that",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 86,
#   "deprel": "nmod",
#   "start_char": 569,
#   "end_char": 573
# })
# ({
#   "id": 86,
#   "text": "humor",
#   "lemma": "humor",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 87,
#   "deprel": "compound",
#   "start_char": 581,
#   "end_char": 586
# }, 'amod', {
#   "id": 85,
#   "text": "honest",
#   "lemma": "honest",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 86,
#   "deprel": "amod",
#   "start_char": 574,
#   "end_char": 580
# })
# ({
#   "id": 87,
#   "text": "lathimo",
#   "lemma": "lathimo",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 89,
#   "deprel": "compound",
#   "start_char": 587,
#   "end_char": 594
# }, 'compound', {
#   "id": 86,
#   "text": "humor",
#   "lemma": "humor",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 87,
#   "deprel": "compound",
#   "start_char": 581,
#   "end_char": 586
# })
# ({
#   "id": 89,
#   "text": "freewil",
#   "lemma": "freewil",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 90,
#   "deprel": "flat",
#   "start_char": 600,
#   "end_char": 607
# }, 'compound', {
#   "id": 87,
#   "text": "lathimo",
#   "lemma": "lathimo",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 89,
#   "deprel": "compound",
#   "start_char": 587,
#   "end_char": 594
# })
# ({
#   "id": 87,
#   "text": "lathimo",
#   "lemma": "lathimo",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 89,
#   "deprel": "compound",
#   "start_char": 587,
#   "end_char": 594
# }, 'flat', {
#   "id": 88,
#   "text": "find",
#   "lemma": "find",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 87,
#   "deprel": "flat",
#   "start_char": 595,
#   "end_char": 599
# })
# ({
#   "id": 90,
#   "text": "necessari",
#   "lemma": "necessari",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 92,
#   "deprel": "flat",
#   "start_char": 608,
#   "end_char": 617
# }, 'flat', {
#   "id": 89,
#   "text": "freewil",
#   "lemma": "freewil",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 90,
#   "deprel": "flat",
#   "start_char": 600,
#   "end_char": 607
# })
# ({
#   "id": 92,
#   "text": "breath",
#   "lemma": "breath",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 93,
#   "deprel": "compound",
#   "start_char": 622,
#   "end_char": 628
# }, 'flat', {
#   "id": 90,
#   "text": "necessari",
#   "lemma": "necessari",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 92,
#   "deprel": "flat",
#   "start_char": 608,
#   "end_char": 617
# })
# ({
#   "id": 92,
#   "text": "breath",
#   "lemma": "breath",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 93,
#   "deprel": "compound",
#   "start_char": 622,
#   "end_char": 628
# }, 'compound', {
#   "id": 91,
#   "text": "air",
#   "lemma": "air",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 92,
#   "deprel": "compound",
#   "start_char": 618,
#   "end_char": 621
# })
# ({
#   "id": 93,
#   "text": "time",
#   "lemma": "time",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 94,
#   "deprel": "compound",
#   "start_char": 629,
#   "end_char": 633
# }, 'compound', {
#   "id": 92,
#   "text": "breath",
#   "lemma": "breath",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 93,
#   "deprel": "compound",
#   "start_char": 622,
#   "end_char": 628
# })
# ({
#   "id": 94,
#   "text": "challeng",
#   "lemma": "challeng",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 96,
#   "deprel": "compound",
#   "start_char": 634,
#   "end_char": 642
# }, 'compound', {
#   "id": 93,
#   "text": "time",
#   "lemma": "time",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 94,
#   "deprel": "compound",
#   "start_char": 629,
#   "end_char": 633
# })
# ({
#   "id": 96,
#   "text": "polit",
#   "lemma": "polit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 97,
#   "deprel": "compound",
#   "start_char": 649,
#   "end_char": 654
# }, 'compound', {
#   "id": 94,
#   "text": "challeng",
#   "lemma": "challeng",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 96,
#   "deprel": "compound",
#   "start_char": 634,
#   "end_char": 642
# })
# ({
#   "id": 96,
#   "text": "polit",
#   "lemma": "polit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 97,
#   "deprel": "compound",
#   "start_char": 649,
#   "end_char": 654
# }, 'compound', {
#   "id": 95,
#   "text": "socal",
#   "lemma": "socal",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 96,
#   "deprel": "compound",
#   "start_char": 643,
#   "end_char": 648
# })
# ({
#   "id": 97,
#   "text": "societi",
#   "lemma": "societi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 655,
#   "end_char": 662
# }, 'compound', {
#   "id": 96,
#   "text": "polit",
#   "lemma": "polit",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 97,
#   "deprel": "compound",
#   "start_char": 649,
#   "end_char": 654
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'conj', {
#   "id": 97,
#   "text": "societi",
#   "lemma": "societi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 655,
#   "end_char": 662
# })
# ({
#   "id": 97,
#   "text": "societi",
#   "lemma": "societi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 655,
#   "end_char": 662
# }, 'case', {
#   "id": 98,
#   "text": "consid",
#   "lemma": "consid",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 97,
#   "deprel": "case",
#   "start_char": 663,
#   "end_char": 669
# })
# ({
#   "id": 97,
#   "text": "societi",
#   "lemma": "societi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 655,
#   "end_char": 662
# }, 'compound', {
#   "id": 99,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 97,
#   "deprel": "compound",
#   "start_char": 670,
#   "end_char": 675
# })
# ({
#   "id": 101,
#   "text": "id",
#   "lemma": "id",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 97,
#   "deprel": "nmod",
#   "start_char": 683,
#   "end_char": 685
# }, 'compound', {
#   "id": 100,
#   "text": "avatar",
#   "lemma": "avatar",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 101,
#   "deprel": "compound",
#   "start_char": 676,
#   "end_char": 682
# })
# ({
#   "id": 97,
#   "text": "societi",
#   "lemma": "societi",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 655,
#   "end_char": 662
# }, 'nmod', {
#   "id": 101,
#   "text": "id",
#   "lemma": "id",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 97,
#   "deprel": "nmod",
#   "start_char": 683,
#   "end_char": 685
# })
# ({
#   "id": 104,
#   "text": "pioneer",
#   "lemma": "pioneer",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 105,
#   "deprel": "compound",
#   "start_char": 700,
#   "end_char": 707
# }, 'case', {
#   "id": 102,
#   "text": "perhap",
#   "lemma": "perhap",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 104,
#   "deprel": "case",
#   "start_char": 686,
#   "end_char": 692
# })
# ({
#   "id": 104,
#   "text": "pioneer",
#   "lemma": "pioneer",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 105,
#   "deprel": "compound",
#   "start_char": 700,
#   "end_char": 707
# }, 'case', {
#   "id": 103,
#   "text": "consid",
#   "lemma": "consid",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 104,
#   "deprel": "case",
#   "start_char": 693,
#   "end_char": 699
# })
# ({
#   "id": 105,
#   "text": "rebel",
#   "lemma": "rebel",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 107,
#   "deprel": "obl",
#   "start_char": 708,
#   "end_char": 713
# }, 'compound', {
#   "id": 104,
#   "text": "pioneer",
#   "lemma": "pioneer",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 105,
#   "deprel": "compound",
#   "start_char": 700,
#   "end_char": 707
# })
# ({
#   "id": 107,
#   "text": "impress",
#   "lemma": "impress",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Fin",
#   "head": 108,
#   "deprel": "parataxis",
#   "start_char": 721,
#   "end_char": 728
# }, 'obl', {
#   "id": 105,
#   "text": "rebel",
#   "lemma": "rebel",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 107,
#   "deprel": "obl",
#   "start_char": 708,
#   "end_char": 713
# })
# ({
#   "id": 107,
#   "text": "impress",
#   "lemma": "impress",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Fin",
#   "head": 108,
#   "deprel": "parataxis",
#   "start_char": 721,
#   "end_char": 728
# }, 'cc', {
#   "id": 106,
#   "text": "whatev",
#   "lemma": "whatev",
#   "upos": "X",
#   "xpos": "FW",
#   "head": 107,
#   "deprel": "cc",
#   "start_char": 714,
#   "end_char": 720
# })
# ({
#   "id": 108,
#   "text": "make",
#   "lemma": "make",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 729,
#   "end_char": 733
# }, 'parataxis', {
#   "id": 107,
#   "text": "impress",
#   "lemma": "impress",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Fin",
#   "head": 108,
#   "deprel": "parataxis",
#   "start_char": 721,
#   "end_char": 728
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'conj', {
#   "id": 108,
#   "text": "make",
#   "lemma": "make",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 729,
#   "end_char": 733
# })
# ({
#   "id": 108,
#   "text": "make",
#   "lemma": "make",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 729,
#   "end_char": 733
# }, 'xcomp', {
#   "id": 109,
#   "text": "blown",
#   "lemma": "blow",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 108,
#   "deprel": "xcomp",
#   "start_char": 734,
#   "end_char": 739
# })
# ({
#   "id": 108,
#   "text": "make",
#   "lemma": "make",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 729,
#   "end_char": 733
# }, 'advmod', {
#   "id": 110,
#   "text": "away",
#   "lemma": "away",
#   "upos": "ADV",
#   "xpos": "RB",
#   "head": 108,
#   "deprel": "advmod",
#   "start_char": 740,
#   "end_char": 744
# })
# ({
#   "id": 108,
#   "text": "make",
#   "lemma": "make",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 10,
#   "deprel": "conj",
#   "start_char": 729,
#   "end_char": 733
# }, 'obj', {
#   "id": 111,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 108,
#   "deprel": "obj",
#   "start_char": 745,
#   "end_char": 750
# })
# ({
#   "id": 111,
#   "text": "bella",
#   "lemma": "bella",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 108,
#   "deprel": "obj",
#   "start_char": 745,
#   "end_char": 750
# }, 'flat', {
#   "id": 112,
#   "text": "truli",
#   "lemma": "truli",
#   "upos": "X",
#   "xpos": "FW",
#   "feats": "Foreign=Yes",
#   "head": 111,
#   "deprel": "flat",
#   "start_char": 751,
#   "end_char": 756
# })
# ({
#   "id": 114,
#   "text": "soul",
#   "lemma": "soul",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 116,
#   "deprel": "compound",
#   "start_char": 763,
#   "end_char": 767
# }, 'compound', {
#   "id": 113,
#   "text": "heart",
#   "lemma": "heart",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 114,
#   "deprel": "compound",
#   "start_char": 757,
#   "end_char": 762
# })
# ({
#   "id": 116,
#   "text": "movi",
#   "lemma": "movi",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 108,
#   "deprel": "obj",
#   "start_char": 774,
# ...
#   "feats": "Number=Sing",
#   "head": 142,
#   "deprel": "nmod:npmod",
#   "start_char": 905,
#   "end_char": 908
# }, 'nmod:poss', {
#   "id": 136,
#   "text": "there",
#   "lemma": "there",
#   "upos": "PRON",
#   "xpos": "PRP$",
#   "feats": "Case=Gen|Number=Plur|Person=3|Poss=Yes|PronType=Prs",
#   "head": 139,
#   "deprel": "nmod:poss",
#   "start_char": 891,
#   "end_char": 896
# })
# ({
#   "id": 139,
#   "text": "lot",
#   "lemma": "lot",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 142,
#   "deprel": "nmod:npmod",
#   "start_char": 905,
#   "end_char": 908
# }, 'compound', {
#   "id": 137,
#   "text": "lot",
#   "lemma": "lot",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 139,
#   "deprel": "compound",
#   "start_char": 897,
#   "end_char": 900
# })
# ({
#   "id": 139,
#   "text": "lot",
#   "lemma": "lot",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 142,
#   "deprel": "nmod:npmod",
#   "start_char": 905,
#   "end_char": 908
# }, 'compound', {
#   "id": 138,
#   "text": "sex",
#   "lemma": "sex",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 139,
#   "deprel": "compound",
#   "start_char": 901,
#   "end_char": 904
# })
# ({
#   "id": 142,
#   "text": "sex",
#   "lemma": "sex",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 145,
#   "deprel": "compound",
#   "start_char": 924,
#   "end_char": 927
# }, 'nmod:npmod', {
#   "id": 139,
#   "text": "lot",
#   "lemma": "lot",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 142,
#   "deprel": "nmod:npmod",
#   "start_char": 905,
#   "end_char": 908
# })
# ({
#   "id": 142,
#   "text": "sex",
#   "lemma": "sex",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 145,
#   "deprel": "compound",
#   "start_char": 924,
#   "end_char": 927
# }, 'amod', {
#   "id": 140,
#   "text": "awkward",
#   "lemma": "awkward",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 142,
#   "deprel": "amod",
#   "start_char": 909,
#   "end_char": 916
# })
# ({
#   "id": 142,
#   "text": "sex",
#   "lemma": "sex",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 145,
#   "deprel": "compound",
#   "start_char": 924,
#   "end_char": 927
# }, 'amod', {
#   "id": 141,
#   "text": "unsexi",
#   "lemma": "unsexi",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 142,
#   "deprel": "amod",
#   "start_char": 917,
#   "end_char": 923
# })
# ({
#   "id": 145,
#   "text": "sex",
#   "lemma": "sex",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 148,
#   "deprel": "nsubj",
#   "start_char": 943,
#   "end_char": 946
# }, 'compound', {
#   "id": 142,
#   "text": "sex",
#   "lemma": "sex",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 145,
#   "deprel": "compound",
#   "start_char": 924,
#   "end_char": 927
# })
# ({
#   "id": 148,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 957,
#   "end_char": 961
# }, 'advmod', {
#   "id": 143,
#   "text": "perhap",
#   "lemma": "perhap",
#   "upos": "ADV",
#   "xpos": "RB",
#   "head": 148,
#   "deprel": "advmod",
#   "start_char": 928,
#   "end_char": 934
# })
# ({
#   "id": 145,
#   "text": "sex",
#   "lemma": "sex",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 148,
#   "deprel": "nsubj",
#   "start_char": 943,
#   "end_char": 946
# }, 'amod', {
#   "id": 144,
#   "text": "realist",
#   "lemma": "realist",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 145,
#   "deprel": "amod",
#   "start_char": 935,
#   "end_char": 942
# })
# ({
#   "id": 148,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 957,
#   "end_char": 961
# }, 'nsubj', {
#   "id": 145,
#   "text": "sex",
#   "lemma": "sex",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 148,
#   "deprel": "nsubj",
#   "start_char": 943,
#   "end_char": 946
# })
# ({
#   "id": 148,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 957,
#   "end_char": 961
# }, 'advmod', {
#   "id": 146,
#   "text": "weve",
#   "lemma": "weve",
#   "upos": "ADV",
#   "xpos": "RB",
#   "head": 148,
#   "deprel": "advmod",
#   "start_char": 947,
#   "end_char": 951
# })
# ({
#   "id": 148,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 957,
#   "end_char": 961
# }, 'advmod', {
#   "id": 147,
#   "text": "ever",
#   "lemma": "ever",
#   "upos": "ADV",
#   "xpos": "RB",
#   "head": 148,
#   "deprel": "advmod",
#   "start_char": 952,
#   "end_char": 956
# })
# ({
#   "id": 10,
#   "text": "expect",
#   "lemma": "expect",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 54,
#   "end_char": 60
# }, 'parataxis', {
#   "id": 148,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 957,
#   "end_char": 961
# })
# ({
#   "id": 151,
#   "text": "effect",
#   "lemma": "effect",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 148,
#   "deprel": "obj",
#   "start_char": 975,
#   "end_char": 981
# }, 'compound', {
#   "id": 149,
#   "text": "film",
#   "lemma": "film",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 151,
#   "deprel": "compound",
#   "start_char": 962,
#   "end_char": 966
# })
# ({
#   "id": 151,
#   "text": "effect",
#   "lemma": "effect",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 148,
#   "deprel": "obj",
#   "start_char": 975,
#   "end_char": 981
# }, 'amod', {
#   "id": 150,
#   "text": "special",
#   "lemma": "special",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 151,
#   "deprel": "amod",
#   "start_char": 967,
#   "end_char": 974
# })
# ({
#   "id": 148,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 957,
#   "end_char": 961
# }, 'obj', {
#   "id": 151,
#   "text": "effect",
#   "lemma": "effect",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 148,
#   "deprel": "obj",
#   "start_char": 975,
#   "end_char": 981
# })
# ({
#   "id": 153,
#   "text": "inspir",
#   "lemma": "inspir",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 154,
#   "deprel": "compound",
#   "start_char": 992,
#   "end_char": 998
# }, 'amod', {
#   "id": 152,
#   "text": "strangest",
#   "lemma": "strange",
#   "upos": "ADJ",
#   "xpos": "JJS",
#   "feats": "Degree=Sup",
#   "head": 153,
#   "deprel": "amod",
#   "start_char": 982,
#   "end_char": 991
# })
# ({
#   "id": 154,
#   "text": "lathimoss",
#   "lemma": "lathimoss",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 158,
#   "deprel": "compound",
#   "start_char": 999,
#   "end_char": 1008
# }, 'compound', {
#   "id": 153,
#   "text": "inspir",
#   "lemma": "inspir",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 154,
#   "deprel": "compound",
#   "start_char": 992,
#   "end_char": 998
# })
# ({
#   "id": 158,
#   "text": "ruffalo",
#   "lemma": "Ruffalo",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "nsubj",
#   "start_char": 1027,
#   "end_char": 1034
# }, 'compound', {
#   "id": 154,
#   "text": "lathimoss",
#   "lemma": "lathimoss",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 158,
#   "deprel": "compound",
#   "start_char": 999,
#   "end_char": 1008
# })
# ({
#   "id": 158,
#   "text": "ruffalo",
#   "lemma": "Ruffalo",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "nsubj",
#   "start_char": 1027,
#   "end_char": 1034
# }, 'amod', {
#   "id": 155,
#   "text": "entir",
#   "lemma": "entir",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 158,
#   "deprel": "amod",
#   "start_char": 1009,
#   "end_char": 1014
# })
# ({
#   "id": 157,
#   "text": "mark",
#   "lemma": "mark",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 158,
#   "deprel": "compound",
#   "start_char": 1022,
#   "end_char": 1026
# }, 'compound', {
#   "id": 156,
#   "text": "career",
#   "lemma": "career",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 157,
#   "deprel": "compound",
#   "start_char": 1015,
#   "end_char": 1021
# })
# ({
#   "id": 158,
#   "text": "ruffalo",
#   "lemma": "Ruffalo",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "nsubj",
#   "start_char": 1027,
#   "end_char": 1034
# }, 'compound', {
#   "id": 157,
#   "text": "mark",
#   "lemma": "mark",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 158,
#   "deprel": "compound",
#   "start_char": 1022,
#   "end_char": 1026
# })
# ({
#   "id": 159,
#   "text": "perform",
#   "lemma": "perform",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 148,
#   "deprel": "parataxis",
#   "start_char": 1035,
#   "end_char": 1042
# }, 'nsubj', {
#   "id": 158,
#   "text": "ruffalo",
#   "lemma": "Ruffalo",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "nsubj",
#   "start_char": 1027,
#   "end_char": 1034
# })
# ({
#   "id": 148,
#   "text": "seen",
#   "lemma": "see",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "parataxis",
#   "start_char": 957,
#   "end_char": 961
# }, 'parataxis', {
#   "id": 159,
#   "text": "perform",
#   "lemma": "perform",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 148,
#   "deprel": "parataxis",
#   "start_char": 1035,
#   "end_char": 1042
# })
# ({
#   "id": 165,
#   "text": "performanceif",
#   "lemma": "performanceif",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "obj",
#   "start_char": 1070,
#   "end_char": 1083
# }, 'compound', {
#   "id": 160,
#   "text": "duncan",
#   "lemma": "duncan",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "compound",
#   "start_char": 1043,
#   "end_char": 1049
# })
# ({
#   "id": 162,
#   "text": "year",
#   "lemma": "year",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "compound",
#   "start_char": 1054,
#   "end_char": 1058
# }, 'advmod', {
#   "id": 161,
#   "text": "far",
#   "lemma": "far",
#   "upos": "ADV",
#   "xpos": "RB",
#   "feats": "Degree=Pos",
#   "head": 162,
#   "deprel": "advmod",
#   "start_char": 1050,
#   "end_char": 1053
# })
# ({
#   "id": 165,
#   "text": "performanceif",
#   "lemma": "performanceif",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "obj",
#   "start_char": 1070,
#   "end_char": 1083
# }, 'compound', {
#   "id": 162,
#   "text": "year",
#   "lemma": "year",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "compound",
#   "start_char": 1054,
#   "end_char": 1058
# })
# ({
#   "id": 165,
#   "text": "performanceif",
#   "lemma": "performanceif",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "obj",
#   "start_char": 1070,
#   "end_char": 1083
# }, 'amod', {
#   "id": 163,
#   "text": "best",
#   "lemma": "good",
#   "upos": "ADJ",
#   "xpos": "JJS",
#   "feats": "Degree=Sup",
#   "head": 165,
#   "deprel": "amod",
#   "start_char": 1059,
#   "end_char": 1063
# })
# ({
#   "id": 165,
#   "text": "performanceif",
#   "lemma": "performanceif",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "obj",
#   "start_char": 1070,
#   "end_char": 1083
# }, 'compound', {
#   "id": 164,
#   "text": "comed",
#   "lemma": "comed",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "compound",
#   "start_char": 1064,
#   "end_char": 1069
# })
# ({
#   "id": 159,
#   "text": "perform",
#   "lemma": "perform",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 148,
#   "deprel": "parataxis",
#   "start_char": 1035,
#   "end_char": 1042
# }, 'obj', {
#   "id": 165,
#   "text": "performanceif",
#   "lemma": "performanceif",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "obj",
#   "start_char": 1070,
#   "end_char": 1083
# })
# ({
#   "id": 171,
#   "text": "season",
#   "lemma": "season",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "appos",
#   "start_char": 1119,
#   "end_char": 1125
# }, 'nmod:poss', {
#   "id": 166,
#   "text": "your",
#   "lemma": "your",
#   "upos": "PRON",
#   "xpos": "PRP$",
#   "feats": "Case=Gen|Person=2|Poss=Yes|PronType=Prs",
#   "head": 171,
#   "deprel": "nmod:poss",
#   "start_char": 1084,
#   "end_char": 1088
# })
# ({
#   "id": 171,
#   "text": "season",
#   "lemma": "season",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "appos",
#   "start_char": 1119,
#   "end_char": 1125
# }, 'compound', {
#   "id": 167,
#   "text": "look",
#   "lemma": "look",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 171,
#   "deprel": "compound",
#   "start_char": 1089,
#   "end_char": 1093
# })
# ({
#   "id": 171,
#   "text": "season",
#   "lemma": "season",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "appos",
#   "start_char": 1119,
#   "end_char": 1125
# }, 'compound', {
#   "id": 168,
#   "text": "cinemat",
#   "lemma": "cinemat",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 171,
#   "deprel": "compound",
#   "start_char": 1094,
#   "end_char": 1101
# })
# ({
#   "id": 171,
#   "text": "season",
#   "lemma": "season",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "appos",
#   "start_char": 1119,
#   "end_char": 1125
# }, 'compound', {
#   "id": 169,
#   "text": "spectacl",
#   "lemma": "spectacl",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 171,
#   "deprel": "compound",
#   "start_char": 1102,
#   "end_char": 1110
# })
# ({
#   "id": 171,
#   "text": "season",
#   "lemma": "season",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "appos",
#   "start_char": 1119,
#   "end_char": 1125
# }, 'compound', {
#   "id": 170,
#   "text": "holiday",
#   "lemma": "holiday",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 171,
#   "deprel": "compound",
#   "start_char": 1111,
#   "end_char": 1118
# })
# ({
#   "id": 165,
#   "text": "performanceif",
#   "lemma": "performanceif",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 159,
#   "deprel": "obj",
#   "start_char": 1070,
#   "end_char": 1083
# }, 'appos', {
#   "id": 171,
#   "text": "season",
#   "lemma": "season",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "appos",
#   "start_char": 1119,
#   "end_char": 1125
# })
# ({
#   "id": 173,
#   "text": "found",
#   "lemma": "find",
#   "upos": "VERB",
#   "xpos": "VBD",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#   "head": 171,
#   "deprel": "acl:relcl",
#   "start_char": 1131,
#   "end_char": 1136
# }, 'nsubj', {
#   "id": 172,
#   "text": "youv",
#   "lemma": "youv",
#   "upos": "PRON",
#   "xpos": "PRP",
#   "feats": "Case=Nom|Number=Sing|Person=2|PronType=Prs",
#   "head": 173,
#   "deprel": "nsubj",
#   "start_char": 1126,
#   "end_char": 1130
# })
# ({
#   "id": 171,
#   "text": "season",
#   "lemma": "season",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 165,
#   "deprel": "appos",
#   "start_char": 1119,
#   "end_char": 1125
# }, 'acl:relcl', {
#   "id": 173,
#   "text": "found",
#   "lemma": "find",
#   "upos": "VERB",
#   "xpos": "VBD",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#   "head": 171,
#   "deprel": "acl:relcl",
#   "start_char": 1131,
#   "end_char": 1136
# })
# ({
#   "id": 173,
#   "text": "found",
#   "lemma": "find",
#   "upos": "VERB",
#   "xpos": "VBD",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#   "head": 171,
#   "deprel": "acl:relcl",
#   "start_char": 1131,
#   "end_char": 1136
# }, 'advmod', {
#   "id": 174,
#   "text": "right",
#   "lemma": "right",
#   "upos": "ADV",
#   "xpos": "RB",
#   "head": 173,
#   "deprel": "advmod",
#   "start_char": 1137,
#   "end_char": 1142
# })
# Named Entities and their counts:
# Counter({'ORDINAL': 360, 'CARDINAL': 320, 'DATE': 120, 'PERSON': 40, 'TIME': 40})

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
'''
The assignment presented a mix of challenges and enjoyable moments, especially when tackling 
questions 1 and 2. Question 3, however, was a bit different from the other two, presenting more 
difficulty and requiring a distinct approach. The time allotted was sufficient to thoroughly engage 
with and complete the assignment, including the more challenging aspects.

'''
